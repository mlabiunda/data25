# %% [markdown]
# <a href="https://colab.research.google.com/github/mlabiunda/data25/blob/main/comandos_python_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🐍 COMANDOS BÁSICOS DE PYTHON PARA DATA SCIENCE 💻

# Imprimir en pantalla
print("Hola mundo")

# Tipo de dato
print(type(3.14))

# Largo de un string
print(len("hola"))

# Pedir datos al usuario
# nombre = input("Ingrese su nombre: ")  # Descomentar si se quiere usar

# Operadores y variables
x = 10
y = 5
print("Suma:", x + y)
print("Resta:", x - y)
print("División:", x / y)
print("Multiplicación:", x * y)
print("Potencia:", x ** 2)

# Listas
lista = [1, 2, 3]
lista.append(4)
print("Lista:", lista)
print("Primer elemento:", lista[0])

# Diccionarios
dicc = {"nombre": "Ana", "edad": 30}
print("Nombre:", dicc["nombre"])

# Condicionales
if x > y:
    print("x es mayor que y")
else:
    print("y es mayor o igual que x")

# Bucle for
for i in range(5):
    print("Iteración:", i)

# Bucle while
while x > 0:
    print("x:", x)
    x -= 1

# Funciones
def saludar(nombre):
    return f"Hola {nombre}"

print(saludar("Belén"))

# Librerías para Data Science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Numpy array
arr = np.array([1, 2, 3])
print("Array:", arr)

# DataFrame con pandas
df = pd.DataFrame({
    "Nombre": ["Ana", "Luis"],
    "Edad": [30, 25]
})

print("Primeras filas del DataFrame:")
print(df.head())

print("Estadísticas del DataFrame:")
print(df.describe())

print("Promedio de edad:", df["Edad"].mean())

# Gráfico simple
df["Edad"].plot(kind="bar")
plt.title("Edades")
plt.xlabel("Índice")
plt.ylabel("Edad")
plt.show()

# Leer y guardar archivos CSV
# df = pd.read_csv("archivo.csv")         # Leer CSV (requiere archivo)
# df.to_csv("salida.csv", index=False)    # Guardar CSV (crea archivo)
